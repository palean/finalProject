# %%
"""Part II. Code to clean the 'data_raw.csv' and get it ready for the recommender system"""

import pandas as pd
import numpy as np
#from pandas.io.json import json_normalize
from operator import itemgetter
import re

# %%
# TESTING  (dentro de la función 'parsing_data')
#header = soup_test.find('div', id='title-and-menu-box')

# %%
# to see what's going on
#df = pd.read_csv('data_raw.csv')
#df.reset_index(drop=True)

# %%
def add_features(hike_df):
    """Function that classifies 12 characteristics into each route """
    
    hike_df['dog_friendly'] = 0
    hike_df['kid_friendly'] = 0
    hike_df['camping'] = 0
    hike_df['trekking'] = 0
    hike_df['near_water'] = 0
    hike_df['mountain_biking'] = 0
    hike_df['great_views'] = 0
    hike_df['bird_watching'] = 0
    hike_df['climbing'] = 0
    hike_df['forests'] = 0
    hike_df['trail_running'] = 0
    hike_df['historic_place'] = 0
    
    for idx, attribute in enumerate(hike_df['hike_attributes']):
        for feature in [el[1:-1] for el in attribute[1:-1].split(', ')]:
            
            if feature == 'apto para perros' or feature == 'perros con correa':
                hike_df['dog_friendly'].iloc[idx] = 1 

            if feature == 'apto para niños':
                hike_df['kid_friendly'].iloc[idx] = 1

            if feature == 'acampada':
                hike_df['camping'].iloc[idx] = 1

            if feature == 'senderismo' or feature == 'excursiones por la naturaleza':
                hike_df['trekking'].iloc[idx] = 1

            if feature == 'río' or feature == 'cascada' or feature =='lago':
                hike_df['near_water'].iloc[idx] = 1

            if feature == 'ciclismo de montaña':
                hike_df['mountain_biking'].iloc[idx] = 1

            if feature == 'vistas' or feature == 'conducción panorámica':
                hike_df['great_views'].iloc[idx] = 1

            if feature == 'observación de aves' or feature == 'fauna':
                hike_df['bird_watching'].iloc[idx] = 1

            if feature == 'escalada' or feature == 'rocoso' or feature =='trepar':
                hike_df['climbing'].iloc[idx] = 1

            if feature == 'bosque' or feature == 'flores silvestres':
                hike_df['forests'].iloc[idx] = 1

            if feature == 'trail running':
                hike_df['trail_running'].iloc[idx] = 1

            if feature == 'lugar histórico':
                hike_df['historic_place'].iloc[idx] = 1

    hike_df.drop('hike_attributes', axis=1, inplace=True)
    return hike_df

# %%
def data_cleaning(df):
    """Function to clean data"""
    
    df = df.drop(columns=['Unnamed: 0'])                                                            # Dropping first column (from last index)
    df['distance'] =  df['distance'].apply(lambda x: re.sub(r'[^0-9.]','', str(x))).astype(float)   # Taking out non-numeric characters
    df['elevation'] =  df['elevation'].apply(lambda x: re.sub(r'[^0-9.]','', str(x))).astype(float) # Taking out non-numeric characters and converting to float
    df['route_type'] =  df['route_type'].apply(lambda x: re.sub(r'\n','',re.sub(r'Tipo de ruta:','',str(x)))) # Keeping the characteristics of the route
    df['difficulty_level'] = df['difficulty_level'].map({'fácil':1,'moderada':2,'difícil':3})       # Converting categoric variable into number level
    df.rename(columns={'distance': 'distance_kms', 'elevation': 'elevation_mts'}, inplace=True)     # Renaming distance and elevation columns just to be aware of its units

    df = df.assign(hikeID=(df.hike_name).astype('category').cat.codes)                              #Assigning hike codes from 0 to 251
    df = df [['hikeID','hike_name','region','distance_kms','elevation_mts','difficulty_level','stars','num_reviews','user_ratings','route_type','hike_attributes']] # Settle order
    df = pd.get_dummies(df, columns=['route_type'],drop_first=True)                                 # There are 3 types: 'Circular', 'De punto a punto' & 'Ida y vuelta'.
    df = add_features(df)                                                                           # Selecting 12 characteristics

    df['user_ratings'] = df['user_ratings'].apply(eval)                                             # Converting the string 'user_ratings' to a list of dictionaries.
    
    return df

# %%
# To see df
#df = data_cleaning(df)
#df

# %%
# Para tener en cuenta
#df[df['num_reviews']>29]

# %%
#type(df['user_ratings'][0][0]) #now, its a list of dicts

# %%
# To see df
#hike_user_rating_df

# %%
def create_rating_df(df):
    """Function to put in separate columns the user and ratings"""
    
    lista_dicts = [l for l in hike_user_rating_df['user_ratings']]      # List of lists where each element contains the dictionary
    rating_df = pd.DataFrame(columns=['hike_name', 'user', 'rating'])   # Empty df
    
    tmp_hikeID = []
    tmp_hike = []
    tmp_user = []
    tmp_rating = []
    
    for i in range(len(df)):                                            # By each element of the df    
        for el in lista_dicts[i]:
            tmp_hikeID.append(df['hikeID'][i])                          # Adding 'hikeID'
            tmp_hike.append(df['hike_name'][i])                         # Adding 'hike_name'
            tmp_user.append(*el)                                        # Adding user name
            tmp_rating.append(list(map(itemgetter(0), el.values()))[0]) # Adding the rating given by the user

    rating_df['hikeID'] = tmp_hikeID
    rating_df['hike_name'] = tmp_hike
    rating_df['user'] = tmp_user
    rating_df['rating'] = tmp_rating

    return rating_df

# %%
def rating_df_cleanup(rating_df):
    
    rating_df['rating'] = rating_df.rating.astype(float)                                  # Turning rating to a float type
    rating_df = rating_df.assign(userID=(rating_df['user']).astype('category').cat.codes) # Assigning user codes from 0 to 659
    rating_df["userID"] = "user_" + (rating_df["userID"]).astype(str)                     # and adding 'user' to characterize userID
    rating_df = rating_df [['hikeID','hike_name','userID','user','rating']]               # Order settling
    
    return(rating_df)

# %%
if __name__ == '__main__':
    
    df = pd.read_csv('data_raw.csv')                                                             # importing data
    df.reset_index(drop=True)
    
    df = data_cleaning(df)                                                                       # Cleaning data. This is the first df

    hike_user_rating_df = df[['hikeID','hike_name','user_ratings']].copy()                       # Creating a new df
    rating_df = create_rating_df(hike_user_rating_df)                                            # Taking user and rating into different columns
    rating_df = rating_df_cleanup(rating_df)                                                     # Cleaning rating_df. This is the second df.
    
    data_ready = pd.merge(df, rating_df, on='hikeID')                                            # Merging 'df' and 'rating_df' by common column 'hikeID'
    
    data_ready = data_ready.drop(columns=['user_ratings','hike_name_y'])                         # Doing some cleanning to 'data_ready'
    data_ready.rename(columns={'hike_name_x': 'hike_name'}, inplace=True)                        
    data_ready = data_ready[['hikeID', 'hike_name', 'region', 'distance_kms', 'elevation_mts',
       'difficulty_level', 'stars', 'num_reviews', 'userID',
       'user', 'rating','route_type_De punto a punto', 'route_type_Ida y vuelta',
       'dog_friendly', 'kid_friendly', 'camping', 'trekking', 'near_water',
       'mountain_biking', 'great_views', 'bird_watching', 'climbing',
       'forests', 'trail_running', 'historic_place']]
    
    data_ready.to_csv('data_ready.csv',index=False)                                              # Creating an unique csv cleaned file

# %%
#data_ready
# Out:
#      hikeID                                         hike_name  \
# 0       247                                   Vizcaya de Lado
# 1         3         Ajusco via Valle de las Cantimploras Loop
# 2       130                                 Las Canastas Loop
# 3       130                                 Las Canastas Loop
# 4       130                                 Las Canastas Loop
# 5       130                                 Las Canastas Loop
# 6       130                                 Las Canastas Loop
# 7       204                          Ruta del Peregrino Talpa
# 8       204                          Ruta del Peregrino Talpa
# 9       237  Tierras Altas, Alta Tension, Muro, Disney and F1
# 10       49                           Cerro Gordo e Izar Loop
# 11       81                 Cuatlapanga via San Jose Teacalco
# 12        5                                    Alligator Cove
# 13      129                               Las Amapas-La Noria
# 14      129                               Las Amapas-La Noria
# 15      250                        Yelapa Upper Cascada Trail
# 16      250                        Yelapa Upper Cascada Trail
# 17      250                        Yelapa Upper Cascada Trail
# 18      246                                 Villa del Palmar
# 19      246                                 Villa del Palmar
# 20      246                                 Villa del Palmar
# 21      246                                 Villa del Palmar
# 22      246                                 Villa del Palmar
# 23      246                                 Villa del Palmar
# 24      226                                 Sierra Santa Rosa
# 25      226                                 Sierra Santa Rosa
# 26       72                                          Cima Sur
# 27       72                                          Cima Sur
# 28       69          Chichen Itza and The Sacred Cenote Trail
# 29       69          Chichen Itza and The Sacred Cenote Trail
# ..      ...                                               ...
# 940      38                    Cascada Ensenada Ruta Circular
# 941      38                    Cascada Ensenada Ruta Circular
# 942     181                                        Pila Trail
# 943     229                               Tecolote Beach Walk
# 944     229                               Tecolote Beach Walk
# 945     229                               Tecolote Beach Walk
# 946     149                         Monte Tlaloc via Rio Frio
# 947     149                         Monte Tlaloc via Rio Frio
# 948     149                         Monte Tlaloc via Rio Frio
# 949      55                                  Cerro San Isidro
# 950      55                                  Cerro San Isidro
# 951      55                                  Cerro San Isidro
# 952      55                                  Cerro San Isidro
# 953      55                                  Cerro San Isidro
# 954      88         Devils Canyon, Wall Street, Devil's Peak
# 955     244                    Valle de Guadelupe Hot Springs
# 956     244                    Valle de Guadelupe Hot Springs
# 957     244                    Valle de Guadelupe Hot Springs
# 958     217                        Sendero Cerra del Borrego
# 959     161                                   Parque Guadiana
# 960     101                   El Pabellon - Cerro del Mirador
# 961     122                                   La Moneda Trail
# 962      11                           Baker-Milton Trail Loop
# 963      11                           Baker-Milton Trail Loop
# 964      11                           Baker-Milton Trail Loop
# 965     123                                  La Paz Beachwalk
# 966     123                                  La Paz Beachwalk
# 967     123                                  La Paz Beachwalk
# 968     109                            Fisherman's Beach Walk
# 969     109                            Fisherman's Beach Walk
#
#                               region  distance_kms  elevation_mts  \
# 0               coahuila de zaragoza           5.6          327.0
# 1                   ciudad de méxico           6.4          506.0
# 2                            chiapas           7.2          341.0
# 3                            chiapas           7.2          341.0
# 4                            chiapas           7.2          341.0
# 5                            chiapas           7.2          341.0
# 6                            chiapas           7.2          341.0
# 7                            jalisco          72.3         2022.0
# 8                            jalisco          72.3         2022.0
# 9                   ciudad de méxico          23.0         1134.0
# 10                  estado de méxico          16.7          862.0
# 11                          tlaxcala           5.6          349.0
# 12                   baja california           8.5          263.0
# 13                           nayarit          14.3         1263.0
# 14                           nayarit          14.3         1263.0
# 15                           jalisco           7.4          163.0
# 16                           jalisco           7.4          163.0
# 17                           jalisco           7.4          163.0
# 18               baja california sur           9.5          358.0
# 19               baja california sur           9.5          358.0
# 20               baja california sur           9.5          358.0
# 21               baja california sur           9.5          358.0
# 22               baja california sur           9.5          358.0
# 23               baja california sur           9.5          358.0
# 24                        guanajuato           8.5          353.0
# 25                        guanajuato           8.5          353.0
# 26                            sonora           3.7          227.0
# 27                            sonora           3.7          227.0
# 28                           yucatán           4.7          103.0
# 29                           yucatán           4.7          103.0
# ..                               ...           ...            ...
# 940                  baja california          15.4          772.0
# 941                  baja california          15.4          772.0
# 942              baja california sur           1.3          127.0
# 943              baja california sur           2.4            5.0
# 944              baja california sur           2.4            5.0
# 945              baja california sur           2.4            5.0
# 946                 estado de méxico          21.6         1176.0
# 947                 estado de méxico          21.6         1176.0
# 948                 estado de méxico          21.6         1176.0
# 949                  baja california           7.2          505.0
# 950                  baja california           7.2          505.0
# 951                  baja california           7.2          505.0
# 952                  baja california           7.2          505.0
# 953                  baja california           7.2          505.0
# 954                  baja california          42.5         3287.0
# 955                  baja california           5.8          101.0
# 956                  baja california           5.8          101.0
# 957                  baja california           5.8          101.0
# 958  veracruz de ignacio de la llave           2.4          255.0
# 959                          durango           2.1           27.0
# 960                          jalisco           2.9          215.0
# 961             coahuila de zaragoza          16.1          846.0
# 962                           sonora          20.0          228.0
# 963                           sonora          20.0          228.0
# 964                           sonora          20.0          228.0
# 965              baja california sur           4.7           27.0
# 966              baja california sur           4.7           27.0
# 967              baja california sur           4.7           27.0
# 968              baja california sur           5.3           40.0
# 969              baja california sur           5.3           40.0
#
#      difficulty_level  stars  num_reviews    userID                     user  \
# 0                   1    5.0            1  user_360          JuanCarlos Leon
# 1                   3    5.0            1  user_350                  Jose F.
# 2                   2    5.0            5  user_156          David Benjamin
# 3                   2    5.0            5  user_156          David Benjamin
# 4                   2    5.0            5  user_156          David Benjamin
# 5                   2    5.0            5  user_156          David Benjamin
# 6                   2    5.0            5  user_156          David Benjamin
# 7                   3    5.0            2  user_153                 Dany Vic
# 8                   3    5.0            2  user_153                 Dany Vic
# 9                   3    5.0            1  user_523          Pedro Perusquia
# 10                  2    5.0            1  user_523          Pedro Perusquia
# 11                  2    5.0            1  user_343           Jorge Carrillo
# 12                  2    4.0            1  user_179             Donna Miller
# 13                  3    5.0            2   user_84                 C Hdez V
# 14                  3    5.0            2    user_6         Adrián Hernández
# 15                  2    4.7            3  user_579                Sharon D.
# 16                  2    4.7            3  user_561            Ross Hutcheon
# 17                  2    4.7            3  user_270          Hayley Crabtree
# 18                  2    5.0            6  user_447              Martin Ruiz
# 19                  2    5.0            6   user_99            Carrie Butler
# 20                  2    5.0            6  user_314           Jeff Remillard
# 21                  2    5.0            6  user_314           Jeff Remillard
# 22                  2    5.0            6  user_601             Teresa Howes
# 23                  2    5.0            6  user_601             Teresa Howes
# 24                  2    4.5            2  user_577              Sergio Cobo
# 25                  2    4.5            2  user_343           Jorge Carrillo
# 26                  2    5.0            2   user_36             Andrea Aello
# 27                  2    5.0            2  user_152           Daniela Salido
# 28                  1    5.0            5  user_596           Tatiana Ocasio
# 29                  1    5.0            5  user_304                 Jason R.
# ..                ...    ...          ...       ...                      ...
# 940                 2    4.0            5  user_307          Javier Guadiana
# 941                 2    4.0            5  user_307          Javier Guadiana
# 942                 2    4.0            1  user_164         Debranne Cingari
# 943                 1    4.3            3   user_69               Bill Crain
# 944                 1    4.3            3  user_165             Denise Crain
# 945                 1    4.3            3   user_69               Bill Crain
# 946                 3    4.3            3  user_343           Jorge Carrillo
# 947                 3    4.3            3  user_343           Jorge Carrillo
# 948                 3    4.3            3  user_459                 Mau Zepe
# 949                 2    3.8            5  user_348    Jose Alfredo Quintero
# 950                 2    3.8            5  user_349         Jose Covarrubias
# 951                 2    3.8            5  user_349         Jose Covarrubias
# 952                 2    3.8            5  user_319         Jeremiah Shivers
# 953                 2    3.8            5  user_348    Jose Alfredo Quintero
# 954                 3    5.0            1   user_85             C'sar Saul S
# 955                 1    5.0            3  user_126                Clau Esco
# 956                 1    5.0            3  user_265  Gustavo Pelosi Ambrozio
# 957                 1    5.0            3  user_486           Mirna Gonzalez
# 958                 1    5.0            1  user_175               Dominic R.
# 959                 1    2.0            1   user_11            Alan Chaparro
# 960                 2    5.0            1  user_138               César Uyoa
# 961                 2    4.0            1  user_302          Janneth Masters
# 962                 2    3.7            3   user_98            Caroline Rohe
# 963                 2    3.7            3  user_450              Mary Raines
# 964                 2    3.7            3  user_606             Timothy Ivey
# 965                 1    4.7            3   user_69               Bill Crain
# 966                 1    4.7            3   user_69               Bill Crain
# 967                 1    4.7            3  user_165             Denise Crain
# 968                 1    4.0            2   user_69               Bill Crain
# 969                 1    4.0            2  user_165             Denise Crain
#
#      ...  camping  trekking  near_water  mountain_biking  great_views  \
# 0    ...        0         1           0                0            1
# 1    ...        0         1           0                0            1
# 2    ...        0         1           1                0            1
# 3    ...        0         1           1                0            1
# 4    ...        0         1           1                0            1
# 5    ...        0         1           1                0            1
# 6    ...        0         1           1                0            1
# 7    ...        1         1           0                0            1
# 8    ...        1         1           0                0            1
# 9    ...        0         1           0                1            1
# 10   ...        0         0           0                1            1
# 11   ...        0         1           0                0            1
# 12   ...        0         1           0                0            1
# 13   ...        1         1           0                0            1
# 14   ...        1         1           0                0            1
# 15   ...        0         1           1                0            1
# 16   ...        0         1           1                0            1
# 17   ...        0         1           1                0            1
# 18   ...        0         1           0                0            1
# 19   ...        0         1           0                0            1
# 20   ...        0         1           0                0            1
# 21   ...        0         1           0                0            1
# 22   ...        0         1           0                0            1
# 23   ...        0         1           0                0            1
# 24   ...        0         1           1                1            0
# 25   ...        0         1           1                1            0
# 26   ...        0         1           0                0            1
# 27   ...        0         1           0                0            1
# 28   ...        0         1           0                0            1
# 29   ...        0         1           0                0            1
# ..   ...      ...       ...         ...              ...          ...
# 940  ...        0         1           1                0            1
# 941  ...        0         1           1                0            1
# 942  ...        0         1           0                0            1
# 943  ...        0         1           0                0            1
# 944  ...        0         1           0                0            1
# 945  ...        0         1           0                0            1
# 946  ...        0         1           1                1            1
# 947  ...        0         1           1                1            1
# 948  ...        0         1           1                1            1
# 949  ...        0         1           0                1            1
# 950  ...        0         1           0                1            1
# 951  ...        0         1           0                1            1
# 952  ...        0         1           0                1            1
# 953  ...        0         1           0                1            1
# 954  ...        1         1           0                0            1
# 955  ...        0         1           0                0            0
# 956  ...        0         1           0                0            0
# 957  ...        0         1           0                0            0
# 958  ...        0         1           0                0            1
# 959  ...        0         0           0                0            0
# 960  ...        0         1           0                0            1
# 961  ...        0         1           0                0            1
# 962  ...        0         1           0                0            1
# 963  ...        0         1           0                0            1
# 964  ...        0         1           0                0            1
# 965  ...        0         1           0                0            1
# 966  ...        0         1           0                0            1
# 967  ...        0         1           0                0            1
# 968  ...        0         1           0                0            1
# 969  ...        0         1           0                0            1
#
#      bird_watching  climbing  forests  trail_running  historic_place
# 0                1         0        1              1               0
# 1                1         0        0              1               0
# 2                1         0        1              0               0
# 3                1         0        1              0               0
# 4                1         0        1              0               0
# 5                1         0        1              0               0
# 6                1         0        1              0               0
# 7                0         0        0              0               0
# 8                0         0        0              0               0
# 9                0         1        1              0               0
# 10               1         0        1              0               0
# 11               1         1        1              1               1
# 12               1         0        0              0               0
# 13               1         0        1              1               0
# 14               1         0        1              1               0
# 15               0         0        0              0               0
# 16               0         0        0              0               0
# 17               0         0        0              0               0
# 18               1         1        0              0               0
# 19               1         1        0              0               0
# 20               1         1        0              0               0
# 21               1         1        0              0               0
# 22               1         1        0              0               0
# 23               1         1        0              0               0
# 24               1         0        1              0               0
# 25               1         0        1              0               0
# 26               0         0        0              0               0
# 27               0         0        0              0               0
# 28               0         0        0              0               1
# 29               0         0        0              0               1
# ..             ...       ...      ...            ...             ...
# 940              0         0        0              0               0
# 941              0         0        0              0               0
# 942              1         0        0              0               0
# 943              0         0        0              0               0
# 944              0         0        0              0               0
# 945              0         0        0              0               0
# 946              1         1        1              0               1
# 947              1         1        1              0               1
# 948              1         1        1              0               1
# 949              1         1        1              1               0
# 950              1         1        1              1               0
# 951              1         1        1              1               0
# 952              1         1        1              1               0
# 953              1         1        1              1               0
# 954              1         0        0              0               0
# 955              0         0        0              0               0
# 956              0         0        0              0               0
# 957              0         0        0              0               0
# 958              1         0        1              0               0
# 959              0         0        0              1               0
# 960              1         0        0              0               0
# 961              0         1        0              0               0
# 962              1         0        0              0               0
# 963              1         0        0              0               0
# 964              1         0        0              0               0
# 965              1         0        0              1               0
# 966              1         0        0              1               0
# 967              1         0        0              1               0
# 968              1         0        0              0               0
# 969              1         0        0              0               0
#
# [970 rows x 25 columns]
